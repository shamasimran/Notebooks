# %% [markdown]
# - **Name:** 22.3_child_notebook
# - **Author:** Shamas Imran
# - **Desciption:** Example of a child notebook to receive parameters
# - **Date:** 19-Aug-2025
# <!--
# REVISION HISTORY
# Version          Date        Author           Desciption
# 01           19-Aug-2025   Shamas Imran       Created child notebook to accept parameters
#                                               Printed parameter values
#                                               Used return statements for output
# -->

# %%
student_name = 'Unknown'
student_age = 'NA'

# %%
from notebookutils import mssparkutils


print(f"Student Name: {student_name}")
print(f"Student Age: {student_age}")

# Return to parent
mssparkutils.notebook.exit(f"Processed student {student_name}, Age {student_age}")
# Out:
# StatementMeta(, 6c136c6c-cf17-4c6d-8aca-22fe92b12c90, 5, Finished, Available, Finished)
# ...
# Student Name: Unknown
# Student Age: N/A
# ExitValue: Processed student Unknown, Age N/A
