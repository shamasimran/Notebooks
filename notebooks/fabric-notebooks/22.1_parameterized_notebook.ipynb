# %% [markdown]
# - **Name:** 22.1_parameterized_notebook
# - **Author:** Shamas Imran
# - **Desciption:** Passing parameter to notebook from a pipeline.
# - **Date:** 03-Nov-2025
# <!--
# REVISION HISTORY
# Version          Date        Author           Desciption
# 01           19-Aug-2025   Shamas Imran       Passing parameter to notebook from pipeline.
# -->

# %%
# PARAMETER
input_path_nb = "/lakehouse/default/Files/raw/patients.csv"
output_table_nb = "clean_patients"
min_age_nb = 18
# Out:
# StatementMeta(, 12f9cb94-ad93-4a97-be8e-533f82629246, 5, Finished, Available, Finished)

# %%
print(f"Input path: {input_path_nb}")
print(f"Output table: {output_table_nb}")
print(f"Minimum age: {min_age_nb}")
# Out:
# StatementMeta(, 12f9cb94-ad93-4a97-be8e-533f82629246, 6, Finished, Available, Finished)
# Input path: /lakehouse/default/Files/raw/patients.csv
# Output table: clean_patients
# Minimum age: 18
