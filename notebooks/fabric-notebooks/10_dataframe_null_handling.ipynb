# %% [markdown]
# - **Name:** 10_dataframe_null_handling
# - **Author:** Shamas Imran
# - **Desciption:** Handling NULL values in DataFrames
# - **Date:** 27-OCT-2025
# <!--
# REVISION HISTORY
# Version          Date        Author           Desciption
# 01           19-Aug-2025   Shamas Imran       Replaced nulls using fillna
#                                               Dropped rows with null values
#                                               Demonstrated coalesce and na functions
# -->

# %%
data = [
    (1, "Shamas", None),
    (2, None, 25),
    (3, "Imran", 30),
    (4, None, None)
]
df = spark.createDataFrame(data, ["id", "name", "age"])

df.show()
# Out:
# StatementMeta(, b39597ec-1910-4a5d-93de-99a71a0bdbe5, 3, Finished, Available, Finished)
# +---+------+----+
# | id|  name| age|
# +---+------+----+
# |  1|Shamas|NULL|
# |  2|  NULL|  25|
# |  3| Imran|  30|
# |  4|  NULL|NULL|
# +---+------+----+

# %%
df.filter(df["name"].isNull()).show()
# Out:
# StatementMeta(, b39597ec-1910-4a5d-93de-99a71a0bdbe5, 4, Finished, Available, Finished)
# +---+----+----+
# | id|name| age|
# +---+----+----+
# |  2|NULL|  25|
# |  4|NULL|NULL|
# +---+----+----+

# %%
df.filter(df["name"].isNotNull()).show()
# Out:
# StatementMeta(, b39597ec-1910-4a5d-93de-99a71a0bdbe5, 5, Finished, Available, Finished)
# +---+------+----+
# | id|  name| age|
# +---+------+----+
# |  1|Shamas|NULL|
# |  3| Imran|  30|
# +---+------+----+

# %%
# Drop rows with any null
df.na.drop().show()
# Out:
# StatementMeta(, b39597ec-1910-4a5d-93de-99a71a0bdbe5, 6, Finished, Available, Finished)
# +---+-----+---+
# | id| name|age|
# +---+-----+---+
# |  3|Imran| 30|
# +---+-----+---+

# %%
# Drop rows only if "name" is NULL
df_filtered = df.na.drop(subset=["name"])
df_filtered.show()
# Out:
# StatementMeta(, b39597ec-1910-4a5d-93de-99a71a0bdbe5, 7, Finished, Available, Finished)
# +---+------+----+
# | id|  name| age|
# +---+------+----+
# |  1|Shamas|NULL|
# |  3| Imran|  30|
# +---+------+----+

# %%
df.fillna("Missing", subset=["name"]).show()
# Out:
# StatementMeta(, b39597ec-1910-4a5d-93de-99a71a0bdbe5, 8, Finished, Available, Finished)
# +---+-------+----+
# | id|   name| age|
# +---+-------+----+
# |  1| Shamas|NULL|
# |  2|Missing|  25|
# |  3|  Imran|  30|
# |  4|Missing|NULL|
# +---+-------+----+

# %%
df.na.fill({"name": "Unknown", "age": 0}).show()
# Out:
# StatementMeta(, b39597ec-1910-4a5d-93de-99a71a0bdbe5, 9, Finished, Available, Finished)
# +---+-------+---+
# | id|   name|age|
# +---+-------+---+
# |  1| Shamas|  0|
# |  2|Unknown| 25|
# |  3|  Imran| 30|
# |  4|Unknown|  0|
# +---+-------+---+

# %%
from pyspark.sql import functions as F

df.withColumn(
    "age",
    F.when(df["age"].isNull(), 99).otherwise(df["age"])
).show()
# Out:
# StatementMeta(, b39597ec-1910-4a5d-93de-99a71a0bdbe5, 11, Finished, Available, Finished)
# +---+------+---+
# | id|  name|age|
# +---+------+---+
# |  1|Shamas| 99|
# |  2|  NULL| 25|
# |  3| Imran| 30|
# |  4|  NULL| 99|
# +---+------+---+
