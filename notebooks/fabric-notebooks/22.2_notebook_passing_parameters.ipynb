# %% [markdown]
# - **Name:** 22.2_notebook_passing_parameters
# - **Author:** Shamas Imran
# - **Desciption:** Passing parameters between Databricks notebooks
# - **Date:** 19-Aug-2025
# <!--
# REVISION HISTORY
# Version          Date        Author           Desciption
# 01           19-Aug-2025   Shamas Imran       Used dbutils.notebook.run for parameter passing
#                                               Defined defaults for parameters
#                                               Demonstrated parent-child notebook execution
# -->

# %%
student_name1 = "Alice"
# Out:
# StatementMeta(, 240348f2-3b95-4c6a-86cf-7d312071a9c4, 3, Finished, Available, Finished)

# %%
from notebookutils import mssparkutils

# Pass parameters directly as a dict
result = mssparkutils.notebook.run(
    "22.3_child_notebook",                 # Notebook name or path
    60,                              # Timeout in seconds
    {"student_name": "Shamas", "student_age": "22"}
)

print("Child result:", result)
# Out:
# StatementMeta(, 240348f2-3b95-4c6a-86cf-7d312071a9c4, 5, Finished, Available, Finished)
# Child result: Processed student Shamas, Age 22
